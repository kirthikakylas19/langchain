# %%
# Core framework and OpenAI integration
# !pip install -U langchain==1.2.9 langchain-openai==1.1.7


# Community tools and Vector Store dependencies
# !pip install -U langchain-community faiss-cpu tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.2.10
#     Uninstalling langchain-1.2.10:
#       Successfully uninstalled langchain-1.2.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ...

# %%
import os
# os.environ["OPENAI_API_KEY"] = "____"

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage,AIMessage,SystemMessage
model = ChatOpenAI(model = 'gpt-3.5-turbo',temperature=0)

# %%
messages = [
    SystemMessage(content = "Act like a seasoned AI professional"),
    HumanMessage(content = "What is the difference between LLMs v/s Chat Models?")
]

# %%
response = model.invoke(messages)
print(response.content)
# Out:
# LLMs (Large Language Models) and Chat Models are both types of natural language processing models, but they serve different purposes and have different capabilities.
#
# LLMs are designed to understand and generate human language at a large scale. They are trained on vast amounts of text data and can perform a wide range of language-related tasks, such as text generation, translation, summarization, and question answering. LLMs like GPT-3 (Generative Pre-trained Transformer 3) are known for their ability to generate coherent and contextually relevant text based on the input they receive.
#
# ...

# %%
# PromptTemplates :

# %%
from langchain_core.prompts import ChatPromptTemplate
template = ChatPromptTemplate.from_messages(
    [
        ("system","You are specialised bot who has knowledge about {topic}"),
        ("human","{question}")
    ]
)

# %%
formatted_prompt = template.format_messages(topic = "LangChain",
                                          question = "How do prompt templated works?")

# %%
print(formatted_prompt)
# Out:
# [SystemMessage(content='You are specialised bot who has knowledge about LangChain', additional_kwargs={}, response_metadata={}), HumanMessage(content='How do prompt templated works?', additional_kwargs={}, response_metadata={})]

# %%
# Chunking :
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# loader = TextLoader('./data/text.txt')
# docs = loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 150,
    chunk_overlap = 10,
    # separators = ["\n"]

)

# %%
text = """
In a world that moves faster every year, the ability to pause and think clearly has become a quiet advantage. Technology has shortened feedback loops, accelerated decision-making, and reduced the distance between ideas and execution. While this speed creates opportunity, it also introduces noise. The challenge for individuals and organizations is no longer access to information, but the ability to filter, interpret, and act with intent. Clarity now matters more than raw intelligence.

Progress rarely comes from dramatic breakthroughs alone; it is usually the result of consistent, incremental improvement. Small habits, repeated daily, compound into meaningful change over time. This principle applies equally to learning new skills, building products, and developing relationships. Sustainable growth depends on patience, discipline, and a willingness to revisit fundamentals even when they feel familiar or mundane.

Equally important is the role of curiosity. Asking better questions often leads to better outcomes than rushing toward premature answers. Curiosity keeps thinking flexible and prevents stagnation. It allows people to adapt when assumptions fail and circumstances change. In uncertain environments, adaptability is not optional—it is a survival skill.
"""
chunks = text_splitter.split_text(text)

# %%
chunks
# Out:
# ['In a world that moves faster every year, the ability to pause and think clearly has become a quiet advantage. Technology has shortened feedback',
#  'feedback loops, accelerated decision-making, and reduced the distance between ideas and execution. While this speed creates opportunity, it also',
#  'it also introduces noise. The challenge for individuals and organizations is no longer access to information, but the ability to filter, interpret,',
#  'and act with intent. Clarity now matters more than raw intelligence.',
#  'Progress rarely comes from dramatic breakthroughs alone; it is usually the result of consistent, incremental improvement. Small habits, repeated',
#  'repeated daily, compound into meaningful change over time. This principle applies equally to learning new skills, building products, and developing',
#  'relationships. Sustainable growth depends on patience, discipline, and a willingness to revisit fundamentals even when they feel familiar or mundane.',
# ...

# %%
# Text Embeddings and Vector Stores

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
embeddings = OpenAIEmbeddings()

# %%
texts = ["LangChain simplifies LLM apps.", "RAG connects models to documents."]
vectorstore = FAISS.from_texts(texts,embeddings)

# %%
retriever = vectorstore.as_retriever(
    search_type = "similarity",
    search_kwargs = {"k":1} # return the most relevant chunk!
)

# %%
relevant_docs = retriever.invoke("What is LangChain?")

# %%
relevant_docs
# Out:
# [Document(id='bdd0c6bc-83fd-400e-8d0b-ac6a9a81f33f', metadata={}, page_content='LangChain simplifies LLM apps.')]

# %%
relevant_docs[0].page_content
# Out:
# 'LangChain simplifies LLM apps.'
